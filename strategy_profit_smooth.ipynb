# %% [markdown]
# # 策略收益率性质分析
#
# ## 观点
# 策略的收益率应当随着时间平滑变化，并且收益率变化是有趋势，可预测的
#
# ## 作用
# 若观点为真，可对策略进行交易
#
# ## 实验设计
# 选取一些策略，使用全品种生成交易，计算交易收益率，平均分配到每一日，每日所有收益率取平均值，观察收益率曲线
#
# > 可能的问题
# > * 全品种可能需要改成主板，或两个都测试
# > * 计算收益率并平均分配到每一日是否合理？可能需要找到理论支撑或用另一个实验验证
# > * 所有收益率取平均值是否合理？可能需要找到理论支撑或用另一个实验验证
# > * 肉眼观察可能不够合理，寻找更客观的方式进行结果的分析
